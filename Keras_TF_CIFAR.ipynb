# %% [markdown]
# # High-level Keras (TF) Example

# %%
import os
import sys
import numpy as np
os.environ['KERAS_BACKEND'] = "tensorflow"
import keras as K
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, Dropout
from common.params import *
from common.utils import *
# Out:
# Using TensorFlow backend.

# %%
print("OS: ", sys.platform)
print("Python: ", sys.version)
print("Keras: ", K.__version__)
print("Numpy: ", np.__version__)
print("Tensorflow: ", tensorflow.__version__)
print(K.backend.backend())
# Channels should be last (otherwise slow)
print(K.backend.image_data_format())
print("GPU: ", get_gpu_name())
# Out:
# OS:  linux
# Python:  3.5.2 |Anaconda custom (64-bit)| (default, Jul  2 2016, 17:53:06)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# Keras:  2.0.8
# Numpy:  1.13.1
# Tensorflow:  1.3.0
# tensorflow
# channels_last
# GPU:  ['Tesla K80', 'Tesla K80', 'Tesla K80', 'Tesla K80']

# %%
os.environ['TF_ENABLE_WINOGRAD_NONFUSED'] = "1"

# %%
def create_symbol():
    model = Sequential()
    
    model.add(Conv2D(50, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(Conv2D(50, kernel_size=(3, 3), padding='same', activation='relu'))    
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(Conv2D(100, kernel_size=(3, 3), padding='same', activation='relu'))
    model.add(Conv2D(100, kernel_size=(3, 3), padding='same', activation='relu'))    
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))
        
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(N_CLASSES, activation='softmax'))
    return model

# %%
def init_model(m):
    m.compile(
        loss = "categorical_crossentropy",
        optimizer = K.optimizers.SGD(LR, MOMENTUM),
        metrics = ['accuracy'])
    return m

# %%
# %%time
# Data into format for library
x_train, x_test, y_train, y_test = cifar_for_library(channel_first=False, one_hot=True)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
print(x_train.dtype, x_test.dtype, y_train.dtype, y_test.dtype)
# Out:
# Downloading http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Done.
# Extracting files...
# Done.
# Preparing train set...
# Preparing test set...
# Done.
# (50000, 32, 32, 3) (10000, 32, 32, 3) (50000, 10) (10000, 10)
# float32 float32 int32 int32
# CPU times: user 3.2 s, sys: 1.84 s, total: 5.04 s
# Wall time: 34.3 s

# %%
# %%time
# Load symbol
sym = create_symbol()
# Out:
# CPU times: user 104 ms, sys: 4 ms, total: 108 ms
# Wall time: 107 ms

# %%
# %%time
# Initialise model
model = init_model(sym)
# Out:
# CPU times: user 24 ms, sys: 0 ns, total: 24 ms
# Wall time: 25.1 ms

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 50)        1400
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 50)        22550
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 50)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 50)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 100)       45100
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 100)       90100
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 100)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 100)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               3277312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,441,592
# Trainable params: 3,441,592
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# Train model
model.fit(x_train,
          y_train,
          batch_size=BATCHSIZE,
          epochs=EPOCHS,
          verbose=1)
# Out:
# Epoch 1/20
#  - ETA: 3s - loss: 1.8582 - acc: 0.3213
# Epoch 2/20
#  - ETA: 0s - loss: 1.3930 - acc: 0.4954
# Epoch 3/20
#  - ETA: 22s - loss: 1.2243 - acc: 0.5576
# Epoch 4/20
#  - ETA: 3s - loss: 1.0005 - acc: 0.6441
# Epoch 5/20
#  - ETA: 6s - loss: 0.8873 - acc: 0.6866
# Epoch 6/20
#  - ETA: 0s - loss: 0.7916 - acc: 0.7208
# Epoch 7/20
#  - ETA: 2s - loss: 0.7211 - acc: 0.7453
# Epoch 8/20
#  - ETA: 13s - loss: 0.6519 - acc: 0.7671
# Epoch 9/20
#  - ETA: 8s - loss: 0.5996 - acc: 0.7863
# Epoch 10/20
#  - ETA: 7s - loss: 0.5527 - acc: 0.8051
# Epoch 11/20
#  - ETA: 1s - loss: 0.5109 - acc: 0.8201
# Epoch 12/20
#  - ETA: 1s - loss: 0.4713 - acc: 0.8318
# Epoch 13/20
#  - ETA: 0s - loss: 0.4432 - acc: 0.8427
# Epoch 14/20
#  - ETA: 10s - loss: 0.3960 - acc: 0.8575
# Epoch 15/20
#  - ETA: 27s - loss: 0.3582 - acc: 0.8721
# Epoch 16/20
# 50000/50000 [==============================] - 37s - loss: 0.3535 - acc: 0.8747
# Epoch 17/20
#  - ETA: 3s - loss: 0.3352 - acc: 0.8806
# Epoch 18/20
#  - ETA: 6s - loss: 0.3073 - acc: 0.8902
# Epoch 19/20
#  - ETA: 1s - loss: 0.2933 - acc: 0.8952
# Epoch 20/20
#  - ETA: 3s - loss: 0.2813 - acc: 0.8999
# CPU times: user 6min 56s, sys: 1min 12s, total: 8min 8s
# Wall time: 12min 23s

# %%
# %%time
y_guess = model.predict(x_test, batch_size=BATCHSIZE)
y_guess = np.argmax(y_guess, axis=-1)
y_truth = np.argmax(y_test, axis=-1)
# Out:
# CPU times: user 1.41 s, sys: 276 ms, total: 1.69 s
# Wall time: 2.35 s

# %%
print("Accuracy: ", sum(y_guess == y_truth)/float(len(y_guess)))
# Out:
# Accuracy:  0.8003
